# %%
from __future__ import print_function
import json
import urllib2 
import os
import sys



My_MTA_key = "857fded5-0cd9-4823-805b-25a91f048372"
MTA_KEY = sys.argv[1]
BUS_LINE = sys.argv[2]

url = "http://bustime.mta.info/api/siri/vehicle-monitoring.json?key=%s&VehicleMonitoringDetailLevel=calls&LineRef=%s"%(MTA_KEY, BUS_LINE)

#url = "http://api.openweathermap.org/data/2.5/forecast/daily?q=%s&mode=%s&units=%s&cnt=7&APPID=%s"%(city, mode, units, apikey)
#<MTA_KEY> <BUS_LINE>
response = urllib2.urlopen(url)
data = response.read().decode("utf-8")
data = json.loads(data)

print (data)
# Out:
# {u'Siri': {u'ServiceDelivery': {u'SituationExchangeDelivery': [{u'Situations': {u'PtSituationElement': [{u'Description': u'b/d B52 buses are detoured, due to road construction on Fulton St & Greene Av. Details at mta.info', u'Consequences': {u'Consequence': [{u'Condition': u'altered'}]}, u'Affects': {u'VehicleJourneys': {u'AffectedVehicleJourney': [{u'DirectionRef': u'0', u'LineRef': u'MTA NYCT_B52'}, {u'DirectionRef': u'1', u'LineRef': u'MTA NYCT_B52'}]}}, u'CreationTime': u'2016-09-16T12:09:14.180-04:00', u'Summary': u'b/d B52 buses are detoured, due to road construction on Fulton St & Greene Av. Details at mta.info', u'PublicationWindow': {u'StartTime': u'2016-09-16T08:02:00.000-04:00'}, u'SituationNumber': u'MTA NYCT_bb78c77d-8063-44e3-8b54-dcc32273dcd0', u'Severity': u'undefined'}]}}], u'ResponseTimestamp': u'2016-09-16T14:12:47.498-04:00', u'VehicleMonitoringDelivery': [{u'VehicleActivity': [{u'RecordedAtTime': u'2016-09-16T14:12:23.000-04:00', u'MonitoredVehicleJourney': {u'OriginRef': u'MTA_307175', u'Bearing': 338.25958, u'VehicleLocation': {u'Latitude': 40.690783, u'Longitude': -73.985662}, u'SituationRef': [{u'SituationSimpleRef': u'MTA NYCT_bb78c77d-8063-44e3-8b54-dcc32273dcd0'}], u'OperatorRef': u'MTA NYCT', u'VehicleRef': u'MTA NYCT_6530', u'BlockRef': u'MTA NYCT_FP_D6-Weekday-SDon_E_FP_22560_B54-208', u'DestinationName': u'RIDGEWOOD TERM via GATES', u'DestinationRef': u'MTA_801117', u'JourneyPatternRef': u'MTA_B520040', u'MonitoredCall': {u'VisitNumber': 1, u'StopPointRef': u'MTA_307491', u'ExpectedDepartureTime': u'2016-09-16T14:12:48.498-04:00', u'StopPointName': u'FULTON ST/HOYT ST', u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 986.34, u'StopsFromCall': 0, u'PresentableDistance': u'at stop', u'DistanceFromCall': 13.3}}, u'ExpectedArrivalTime': u'2016-09-16T14:12:48.498-04:00'}, u'LineRef': u'MTA NYCT_B52', u'FramedVehicleJourneyRef': {u'DataFrameRef': u'2016-09-16', u'DatedVehicleJourneyRef': u'MTA NYCT_FP_D6-Weekday-SDon-082000_B54_217'}, u'PublishedLineName': u'B52', u'Monitored': True, u'OnwardCalls': {u'OnwardCall': [{u'VisitNumber': 1, u'StopPointRef': u'MTA_307491', u'ExpectedDepartureTime': u'2016-09-16T14:12:47.498-04:00', u'StopPointName': u'FULTON ST/HOYT ST', u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 986.34, u'StopsFromCall': 0, u'PresentableDistance': u'at stop', u'DistanceFromCall': 13.3}}, u'ExpectedArrivalTime': u'2016-09-16T14:12:47.498-04:00'}, {u'VisitNumber': 1, u'StopPointRef': u'MTA_302947', u'ExpectedDepartureTime': u'2016-09-16T14:14:58.800-04:00', u'StopPointName': u'FULTON ST/BOND ST', u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 1219.82, u'StopsFromCall': 1, u'PresentableDistance': u'1 stop away', u'DistanceFromCall': 246.78}}, u'ExpectedArrivalTime': u'2016-09-16T14:14:58.800-04:00'}, {u'VisitNumber': 1, u'StopPointRef': u'MTA_302948', u'ExpectedDepartureTime': u'2016-09-16T14:16:31.600-04:00', u'StopPointName': u'FULTON ST/FLATBUSH AV EXT', u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 1393.75, u'StopsFromCall': 2, u'PresentableDistance': u'2 stops away', u'DistanceFromCall': 420.71}}, u'ExpectedArrivalTime': u'2016-09-16T14:16:31.600-04:00'}, {u'VisitNumber': 1, u'StopPointRef': u'MTA_303017', u'ExpectedDepartureTime': u'2016-09-16T14:19:03.313-04:00', u'StopPointName': u'FULTON ST/ASHLAND PL', u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 1683.14, u'StopsFromCall': 3, u'PresentableDistance': u'3 stops away', u'DistanceFromCall': 710.09}}, u'ExpectedArrivalTime': u'2016-09-16T14:19:03.313-04:00'}, {u'VisitNumber': 1, u'StopPointRef': u'MTA_302368', u'ExpectedDepartureTime': u'2016-09-16T14:19:49.404-04:00', u'StopPointName': u'FULTON ST/LAFAYETTE AV', u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 1831.54, u'StopsFromCall': 4, u'PresentableDistance': u'0.5 miles away', u'DistanceFromCall': 858.5}}, u'ExpectedArrivalTime': u'2016-09-16T14:19:49.404-04:00'}, {u'VisitNumber': 1, u'StopPointRef': u'MTA_302369 ...

# %%
(type(data))
# Out:
# dict

# %%
data.keys()
# Out:
# [u'Siri']

# %%
with open('data.txt', 'w') as outfile:
    json.dump(data, outfile)

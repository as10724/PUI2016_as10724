# %%
from __future__ import print_function, division
import pandas as pd
import pylab as pl
import os
import json
import seaborn
import statsmodels.formula.api as smf
import scipy.stats
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
data1 = pd.read_csv('PollutionData_Delhi_Nov_2015.csv')
data1.head()
# Out:
#    Unnamed: 0 Unnamed: 1 Unnamed: 2    pm25     rh     at   ws
# 0  2015-11-04   00:00:00   00:59:00  355.00  78.50  16.60  0.3
# 1  2015-11-04   01:00:00   01:59:00  304.00  79.92  16.18  0.3
# 2  2015-11-04   02:00:00   02:59:00  309.50  80.75  15.87  0.3
# 3  2015-11-04   03:00:00   03:59:00  334.83  81.50  15.48  0.3
# 4  2015-11-04   04:00:00   04:59:00  322.00  82.00  15.18  0.3

# %%
data1['dtstr'] = data1['Unnamed: 0'] + data1['Unnamed: 1'] 
data1['dtstr']
# Out:
# 0      2015-11-0400:00:00
# 1      2015-11-0401:00:00
# 2      2015-11-0402:00:00
# 3      2015-11-0403:00:00
# 4      2015-11-0404:00:00
# 5      2015-11-0405:00:00
# 6      2015-11-0406:00:00
# 7      2015-11-0407:00:00
# 8      2015-11-0408:00:00
# 9      2015-11-0409:00:00
# 10     2015-11-0410:00:00
# 11     2015-11-0411:00:00
# 12     2015-11-0412:00:00
# 13     2015-11-0413:00:00
# 14     2015-11-0414:00:00
# 15     2015-11-0415:00:00
# 16     2015-11-0416:00:00
# 17     2015-11-0417:00:00
# 18     2015-11-0418:00:00
# 19     2015-11-0419:00:00
# 20     2015-11-0420:00:00
# 21     2015-11-0421:00:00
# 22     2015-11-0422:00:00
# 23     2015-11-0423:00:00
# 24     2015-11-0500:00:00
# 25     2015-11-0501:00:00
# 26     2015-11-0502:00:00
# 27     2015-11-0503:00:00
# 28     2015-11-0504:00:00
# 29     2015-11-0505:00:00
#               ...
# 664    2015-11-2918:00:00
# 665    2015-11-2919:00:00
# 666    2015-11-2920:00:00
# 667    2015-11-2921:00:00
# 668    2015-11-2922:00:00
# ...

# %%
data1.head()
# Out:
#    Unnamed: 0 Unnamed: 1 Unnamed: 2    pm25     rh     at   ws  \
# 0  2015-11-04   00:00:00   00:59:00  355.00  78.50  16.60  0.3
# 1  2015-11-04   01:00:00   01:59:00  304.00  79.92  16.18  0.3
# 2  2015-11-04   02:00:00   02:59:00  309.50  80.75  15.87  0.3
# 3  2015-11-04   03:00:00   03:59:00  334.83  81.50  15.48  0.3
# 4  2015-11-04   04:00:00   04:59:00  322.00  82.00  15.18  0.3
#
#                 dtstr
# 0  2015-11-0400:00:00
# 1  2015-11-0401:00:00
# 2  2015-11-0402:00:00
# 3  2015-11-0403:00:00
# 4  2015-11-0404:00:00

# %%
data = data1[[u'pm25', u'rh', u'at', u'ws', 'dtstr']]
data.columns
# Out:
# Index(['pm25', 'rh', 'at', 'ws', 'dtstr'], dtype='object')

# %%
data.columns = [[u'pm25', u'rh', u'temp', u'ws', 'dtstr']]
data.columns
# Out:
# Index(['pm25', 'rh', 'temp', 'ws', 'dtstr'], dtype='object')

# %%
# Would like to plot the graph for durinal timeframe so as to account for rush-hours and solar insolation

# %%
import seaborn as sns
current_palette = sns.color_palette('colorblind')
sns.palplot(current_palette)
#sns.palplot('colorblind')
#Not sure if this insures the plots below are colour-blind friendly

# %%
Regressd = smf.ols(formula = 'pm25 ~ rh + temp + ws', data = data).fit()

Regressd.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   pm25   R-squared:                       0.169
# Model:                            OLS   Adj. R-squared:                  0.165
# Method:                 Least Squares   F-statistic:                     43.86
# Date:                Fri, 21 Oct 2016   Prob (F-statistic):           8.11e-26
# Time:                        21:49:22   Log-Likelihood:                -3994.4
# No. Observations:                 653   AIC:                             7997.
# Df Residuals:                     649   BIC:                             8015.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept    174.5240     49.788      3.505      0.000        76.758   272.290
# ...

# %%
data.plot(kind='scatter', x= 'ws', y='rh', 
                fontsize=22, colormap='RdBu_r', alpha = .75, 
                marker='o',  figsize=(16, 14),
                s=(data['pm25'] * 2), 
                c=data['temp'])
pl.title('Color maps Temperature in Celsius, Size maps Hourly PM2.5 concentration', fontsize=18)
pl.ylabel("Relative humidity", fontsize=22)
pl.xlabel("Wind speed", fontsize=22)

# %%
data.plot(kind='scatter', x= 'temp', y='pm25', 
                fontsize=22, colormap='gist_heat_r', alpha = .95, 
                marker='o',  figsize=(16, 14),
                s=(data['ws'] * 500), 
                c=data['rh'])
pl.title('Color maps Relative Humidity, Size maps wind speed', fontsize=18)
pl.ylabel("Hourly PM2.5 concentration", fontsize=22)
pl.xlabel("Temperature in Celsius", fontsize=22)
pl.legend()
# Out:
# /opt/rh/anaconda/root/envs/PUI2016_Python3/lib/python3.5/site-packages/matplotlib/axes/_axes.py:519: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %%
data.plot(kind='scatter', x= 'temp', y='pm25', 
                fontsize=22, colormap='gist_heat_r', alpha = .95, 
                marker='o',  figsize=(16, 14),
                s=(data['rh'] * 10), 
                c=data['ws'])
pl.title('Color maps wind speed, Size maps Relative Humidity', fontsize=18)
pl.ylabel("Hourly PM2.5 concentration", fontsize=22)
pl.xlabel("Temperature in Celsius", fontsize=22)

# %%
data.plot(kind='scatter', x= 'temp', y='pm25', 
                fontsize=22, colormap='RdBu', alpha = .95, 
                marker='o',  figsize=(16, 14),
                s=(data['pm25']), 
                c=data['ws'])
pl.title('Color maps temperature, Size maps wind speed', fontsize=18)
pl.ylabel("Hourly PM2.5 concentration", fontsize=22)
pl.xlabel("Temperature in Celsius", fontsize=22)

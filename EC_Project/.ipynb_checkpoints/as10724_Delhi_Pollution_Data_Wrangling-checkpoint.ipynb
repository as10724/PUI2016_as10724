# %% [markdown]
# # Wrangling Delhi Pollution Data
#
# ### Author: Avikal Somvanshi

# %%
from __future__ import print_function, division
import pandas as pd
import pylab as pl
import os
import csv
import seaborn
import statsmodels.formula.api as smf
import scipy.stats
from pandas.tools.plotting import scatter_matrix
import sys
reload(sys)
sys.setdefaultencoding('utf-8')
# %pylab inline
# Out:
# /opt/rh/anaconda/root/envs/PUI2016_Python2/lib/python2.7/site-packages/IPython/html.py:14: ShimWarning: The `IPython.html` package has been deprecated. You should import from `notebook` instead. `IPython.html.widgets` has moved to `ipywidgets`.
#   "`IPython.html.widgets` has moved to `ipywidgets`.", ShimWarning)

# %% [markdown]
# # The data was downloaded from the website of Central Pollution Control Board of India (Indian equalvalent of EPA).
# # The website allows to download only excel files one parameter and three months at a time.
# # The data consist of hourly measurements of three pollutants and four weather elements from the RK Puram Pollution Monitoring Station of Delhi Government located in Southern Delhi from April 2015 to November 2016.
# # Data is spread across 49 excel files. All the excel files are stored on my local machine, therefore I'm wrangling and writing them on to a csv to be used for further analysis.

# %%
#Reading and saving downloaded PM2.5 data in a dataframe

rk_pm = pd.DataFrame()

for i in range (1,8):
    data = pd.read_excel('data/CPCBAirQualityDataReport_20-11-2016_pm_0' + str(i) + '.xlsx', header=16)
    data = data[:-2]
    data = data[['From (Time)', 'To', 'Date', 'Concentration']]
    data.rename(columns={'Concentration':'PM2.5_Concentration(microgram/m3)'}, inplace=True)
    rk_pm = pd.concat([rk_pm, data])
    
len(rk_pm)
# Out:
# 12424

# %%
#Reading and saving downloaded Ozone data in a dataframe

rk_o3 = pd.DataFrame()

for i in range (1,8):
    data = pd.read_excel('data/CPCBAirQualityDataReport_20-11-2016_o3_0' + str(i) + '.xlsx', header=16)
    data = data[:-2]
    data = data[['From (Time)', 'To', 'Date', 'Concentration']]
    data.rename(columns={'Concentration':'Ozone_Concentration(microgram/m3)'}, inplace=True)
    rk_o3 = pd.concat([rk_o3, data])
    
len(rk_o3)
# Out:
# 12773

# %%
#Reading and saving downloaded NOx data in a dataframe

rk_nox = pd.DataFrame()

for i in range (1,8):
    data = pd.read_excel('data/CPCBAirQualityDataReport_20-11-2016_nox_0' + str(i) + '.xlsx', header=16)
    data = data[:-2]
    data = data[['From (Time)', 'To', 'Date', 'Concentration']]
    data.rename(columns={'Concentration':'NOx_Concentration(ppb)'}, inplace=True)
    rk_nox = pd.concat([rk_nox, data])
    
len(rk_nox)
# Out:
# 12781

# %%
#Reading and saving downloaded temperature data in a dataframe

rk_at = pd.DataFrame()

for i in range (1,8):
    data = pd.read_excel('data/CPCBAirQualityDataReport_20-11-2016_at_0' + str(i) + '.xlsx', header=16)
    data = data[:-2]
    data = data[['From (Time)', 'To', 'Date', 'Concentration']]
    data.rename(columns={'Concentration':'Temperature(Celsius)'}, inplace=True)
    rk_at = pd.concat([rk_at, data])
    
len(rk_at)
# Out:
# 12964

# %%
#Reading and saving downloaded Relative Humidity data in a dataframe

rk_rh = pd.DataFrame()

for i in range (1,8):
    data = pd.read_excel('data/CPCBAirQualityDataReport_20-11-2016_rh_0' + str(i) + '.xlsx', header=16)
    data = data[:-2]
    data = data[['From (Time)', 'To', 'Date', 'Concentration']]
    data.rename(columns={'Concentration':'Relative_Humidity(%)'}, inplace=True)
    rk_rh = pd.concat([rk_rh, data])
    
len(rk_rh)
# Out:
# 12976

# %%
#Reading and saving downloaded wind speed data in a dataframe

rk_ws = pd.DataFrame()

for i in range (1,8):
    data = pd.read_excel('data/CPCBAirQualityDataReport_20-11-2016_ws_0' + str(i) + '.xlsx', header=16)
    data = data[:-2]
    data = data[['From (Time)', 'To', 'Date', 'Concentration']]
    data.rename(columns={'Concentration':'Wind_Speed(m/s)'}, inplace=True)
    rk_ws = pd.concat([rk_ws, data])
    
len(rk_ws)
# Out:
# 12976

# %%
#Reading and saving downloaded solar radiation data in a dataframe

rk_sr = pd.DataFrame()

for i in range (1,8):
    data = pd.read_excel('data/CPCBAirQualityDataReport_20-11-2016_sr_0' + str(i) + '.xlsx', header=16)
    data = data[:-2]
    data = data[['From (Time)', 'To', 'Date', 'Concentration']]
    data.rename(columns={'Concentration':'Solar_Radiation(w/m2)'}, inplace=True)
    rk_sr = pd.concat([rk_sr, data])
    
len(rk_sr)
# Out:
# 12964

# %%
#Merging all the dataframes to a mother dataframe

rk = pd.merge(rk_pm, rk_o3, on=['From (Time)', 'To', 'Date'])
rk = pd.merge(rk, rk_nox, on=['From (Time)', 'To', 'Date'])
rk = pd.merge(rk, rk_at, on=['From (Time)', 'To', 'Date'])
rk = pd.merge(rk, rk_ws, on=['From (Time)', 'To', 'Date'])
rk = pd.merge(rk, rk_rh, on=['From (Time)', 'To', 'Date'])
rk = pd.merge(rk, rk_sr, on=['From (Time)', 'To', 'Date'])
rk.head()
# Out:
#   From (Time)      To Date  PM2.5_Concentration(microgram/m3)  \
# 0         NaN  (Time)  NaN                                NaN
# 1         NaN  (Time)  NaN                                NaN
# 2         NaN  (Time)  NaN                                NaN
# 3         NaN  (Time)  NaN                                NaN
# 4         NaN  (Time)  NaN                                NaN
#
#    Ozone_Concentration(microgram/m3)  NOx_Concentration(ppb)  \
# 0                                NaN                     NaN
# 1                                NaN                     NaN
# 2                                NaN                     NaN
# 3                                NaN                     NaN
# 4                                NaN                     NaN
#
#    Temperature(Celsius)  Wind_Speed(m/s)  Relative_Humidity(%)  \
# 0                   NaN              NaN                   NaN
# 1                   NaN              NaN                   NaN
# 2                   NaN              NaN                   NaN
# 3                   NaN              NaN                   NaN
# 4                   NaN              NaN                   NaN
#
#    Solar_Radiation(w/m2)
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN

# %%
#counting size of mother dataset
len(rk)
# Out:
# 855465

# %%
#The mother dataset is almost 80 times the size of individual sub-dataset. 
#Quick examination of the dataset reveals that there are multiple duplicates
#Removing duplicates via groupby

pollution_Delhi1 = rk.groupby(['From (Time)', 'To', 'Date']).mean()
pollution_Delhi1.reset_index(inplace=True)
pollution_Delhi1.describe()
# Out:
#        PM2.5_Concentration(microgram/m3)  Ozone_Concentration(microgram/m3)  \
# count                       11693.000000                       11782.000000
# mean                          127.671341                          51.893113
# std                           115.125828                          61.026988
# min                            10.170000                           1.030000
# 25%                                  NaN                                NaN
# 50%                                  NaN                                NaN
# 75%                                  NaN                                NaN
# max                           985.000000                         492.520000
#
#        NOx_Concentration(ppb)  Temperature(Celsius)  Wind_Speed(m/s)  \
# count            11855.000000          11856.000000     11856.000000
# mean               168.641692             25.245209         1.214934
# std                211.457149              8.119243         0.879161
# min                  6.600000              1.660000         0.300000
# 25%                       NaN             20.517500         0.380000
# 50%                       NaN             26.120000         1.030000
# 75%                       NaN             30.850000         1.810000
# max               1532.820000             44.680000         7.180000
#
#        Relative_Humidity(%)  Solar_Radiation(w/m2)
# count          11856.000000           11856.000000
# mean              54.381272             112.831123
# std               20.365264             144.420861
# min                7.000000               1.180000
# 25%               37.920000               3.250000
# 50%               56.080000              11.540000
# 75%               71.670000             246.190000
# max               88.130000             420.830000

# %%
pollution_Delhi1.head()
# Out:
#   From (Time)         To         Date  PM2.5_Concentration(microgram/m3)  \
# 0   ┬á00:00:00  ┬á00:59:00  ┬á01/01/2016                             445.00
# 1   ┬á00:00:00  ┬á00:59:00  ┬á01/02/2016                             193.00
# 2   ┬á00:00:00  ┬á00:59:00  ┬á01/03/2016                             229.83
# 3   ┬á00:00:00  ┬á00:59:00  ┬á01/05/2015                              76.83
# 4   ┬á00:00:00  ┬á00:59:00  ┬á01/06/2015                              67.00
#
#    Ozone_Concentration(microgram/m3)  NOx_Concentration(ppb)  \
# 0                              11.22                  536.23
# 1                               7.96                  139.68
# 2                              12.87                  916.78
# 3                              56.25                   58.68
# 4                              25.74                   68.74
#
#    Temperature(Celsius)  Wind_Speed(m/s)  Relative_Humidity(%)  \
# 0                  7.72             0.32                 75.75
# 1                  9.95             0.49                 77.92
# 2                 15.27             0.30                 80.00
# 3                 27.89             1.92                 49.58
# 4                 28.31             1.12                 30.75
#
#    Solar_Radiation(w/m2)
# 0                   3.00
# 1                   2.92
# 2                   3.17
# 3                   3.17
# 4                   3.25

# %%
#Making a datetime index

pollution_Delhi1['datetime'] = pd.to_datetime(pollution_Delhi1['From (Time)'] + " " + pollution_Delhi1['Date'], dayfirst=True)
pollution_Delhi1.index = pd.DatetimeIndex(pollution_Delhi1.datetime)
pollution_Delhi1.head(10)
# Out:
#            From (Time)         To         Date  \
# 2016-01-01   ┬á00:00:00  ┬á00:59:00  ┬á01/01/2016
# 2016-02-01   ┬á00:00:00  ┬á00:59:00  ┬á01/02/2016
# 2016-03-01   ┬á00:00:00  ┬á00:59:00  ┬á01/03/2016
# 2015-05-01   ┬á00:00:00  ┬á00:59:00  ┬á01/05/2015
# 2015-06-01   ┬á00:00:00  ┬á00:59:00  ┬á01/06/2015
# 2016-06-01   ┬á00:00:00  ┬á00:59:00  ┬á01/06/2016
# 2015-07-01   ┬á00:00:00  ┬á00:59:00  ┬á01/07/2015
# 2016-07-01   ┬á00:00:00  ┬á00:59:00  ┬á01/07/2016
# 2015-08-01   ┬á00:00:00  ┬á00:59:00  ┬á01/08/2015
# 2015-09-01   ┬á00:00:00  ┬á00:59:00  ┬á01/09/2015
#
#             PM2.5_Concentration(microgram/m3)  \
# 2016-01-01                             445.00
# 2016-02-01                             193.00
# 2016-03-01                             229.83
# 2015-05-01                              76.83
# 2015-06-01                              67.00
# 2016-06-01                              43.33
# 2015-07-01                              55.00
# 2016-07-01                              54.17
# 2015-08-01                              23.17
# 2015-09-01                              53.50
#
#             Ozone_Concentration(microgram/m3)  NOx_Concentration(ppb)  \
# 2016-01-01                              11.22                  536.23
# 2016-02-01                               7.96                  139.68
# 2016-03-01                              12.87                  916.78
# 2015-05-01                              56.25                   58.68
# 2015-06-01                              25.74                   68.74
# 2016-06-01                              14.95                   70.67
# 2015-07-01                              13.78                  142.87
# 2016-07-01                              20.43                   24.77
# 2015-08-01                              16.47                   68.52
# 2015-09-01                               7.92                   80.04
#
#             Temperature(Celsius)  Wind_Speed(m/s)  Relative_Humidity(%)  \
# 2016-01-01                  7.72             0.32                 75.75
# 2016-02-01                  9.95             0.49                 77.92
# 2016-03-01                 15.27             0.30                 80.00
# 2015-05-01                 27.89             1.92                 49.58
# 2015-06-01                 28.31             1.12                 30.75
# 2016-06-01                 26.43             0.89                 47.75
# 2015-07-01                 25.52             0.73                 69.92
# 2016-07-01                 29.21             1.23                 71.33
# 2015-08-01                 24.84             2.07                 72.25
# 2015-09-01                 27.42             0.63                 64.92
#
#             Solar_Radiation(w/m2)   datetime
# 2016-01-01                   3.00 2016-01-01
# 2016-02-01                   2.92 2016-02-01
# 2016-03-01                   3.17 2016-03-01
# 2015-05-01                   3.17 2015-05-01
# 2015-06-01                   3.25 2015-06-01
# 2016-06-01                   3.00 2016-06-01
# 2015-07-01                   3.92 2015-07-01
# 2016-07-01                   3.00 2016-07-01
# 2015-08-01                   4.00 2015-08-01
# 2015-09-01                   3.42 2015-09-01

# %%
#dropping unwanted columns

pollution_Delhi1.drop(['From (Time)', 'Date', 'datetime', 'To'], 1, inplace=True)
pollution_Delhi1.sort_index(ascending=True, inplace=True)
pollution_Delhi1.head()
# Out:
#                      PM2.5_Concentration(microgram/m3)  \
# 2015-04-04 10:00:00                              58.22
# 2015-04-04 11:00:00                              37.67
# 2015-04-04 12:00:00                              36.00
# 2015-04-04 14:00:00                              32.00
# 2015-04-04 15:00:00                              32.17
#
#                      Ozone_Concentration(microgram/m3)  \
# 2015-04-04 10:00:00                              37.23
# 2015-04-04 11:00:00                              53.48
# 2015-04-04 12:00:00                              96.23
# 2015-04-04 14:00:00                              75.14
# 2015-04-04 15:00:00                              69.67
#
#                      NOx_Concentration(ppb)  Temperature(Celsius)  \
# 2015-04-04 10:00:00                   44.67                 17.57
# 2015-04-04 11:00:00                   43.51                 20.02
# 2015-04-04 12:00:00                   32.07                 20.99
# 2015-04-04 14:00:00                   28.03                 23.53
# 2015-04-04 15:00:00                   32.95                 22.97
#
#                      Wind_Speed(m/s)  Relative_Humidity(%)  \
# 2015-04-04 10:00:00             1.88                 78.33
# 2015-04-04 11:00:00             1.72                 65.00
# 2015-04-04 12:00:00             1.30                 58.17
# 2015-04-04 14:00:00             1.86                 49.92
# 2015-04-04 15:00:00             1.91                 49.67
#
#                      Solar_Radiation(w/m2)
# 2015-04-04 10:00:00                 332.44
# 2015-04-04 11:00:00                 333.83
# 2015-04-04 12:00:00                 311.33
# 2015-04-04 14:00:00                 374.25
# 2015-04-04 15:00:00                 316.75

# %%
#Checking dataset

scatter_matrix(pollution_Delhi1, s=300, figsize=(16, 16))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000000003C80518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000D130668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000CEE2160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000D849AC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000CF6FBE0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000D0817B8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000D977160>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000000000DA65080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000DB5CCC0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000DBBEC88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000DD03B70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000DC72E10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000DEB7128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000DFB1C18>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000000000E01F4E0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000E117E48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000E16FD30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000E3027B8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000E334F28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000E477048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000E56E9B0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000000000E612BA8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000E6D6550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000011801198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000000118BDD30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000000119C56D8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000011A5A240>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000011B51898>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000000011BFF7F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000011D43F60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000011E0B9E8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000011EB3CF8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000011FBA828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000001209E898>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000001212C470>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000000120BAF28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000012317D30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000001241F5F8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000001247FC18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000000125872B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000012677240>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000000127745F8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000000126BC630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000001291C7F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000012A23320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000012AC3A58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000012B8C400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000012C6F2E8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000012D25D30>]], dtype=object)

# %% [markdown]
# #### Caption: All columns are plotable.

# %%
#Saving the dataset as csv

pollution_Delhi1.to_csv('Delhi_pollution_data_RK.csv')

# %%
#Checking the CSV

data = pd.read_csv('Delhi_pollution_data_RK.csv', parse_dates=[0], infer_datetime_format=True, dayfirst=True)
data.head()
# Out:
#            Unnamed: 0  PM2.5_Concentration(microgram/m3)  \
# 0 2015-04-04 10:00:00                              58.22
# 1 2015-04-04 11:00:00                              37.67
# 2 2015-04-04 12:00:00                              36.00
# 3 2015-04-04 14:00:00                              32.00
# 4 2015-04-04 15:00:00                              32.17
#
#    Ozone_Concentration(microgram/m3)  NOx_Concentration(ppb)  \
# 0                              37.23                   44.67
# 1                              53.48                   43.51
# 2                              96.23                   32.07
# 3                              75.14                   28.03
# 4                              69.67                   32.95
#
#    Temperature(Celsius)  Wind_Speed(m/s)  Relative_Humidity(%)  \
# 0                 17.57             1.88                 78.33
# 1                 20.02             1.72                 65.00
# 2                 20.99             1.30                 58.17
# 3                 23.53             1.86                 49.92
# 4                 22.97             1.91                 49.67
#
#    Solar_Radiation(w/m2)
# 0                 332.44
# 1                 333.83
# 2                 311.33
# 3                 374.25
# 4                 316.75

# %% [markdown]
# # Good to go!
